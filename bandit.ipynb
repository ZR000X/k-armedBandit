# %%
from bandit import bp1

a = bp1(
    k=10, 
    var=1,
    N=1000, 
    step=1,
    explore=0.5,
    figures=True
)

# %%
from bandit import compare_exploration
import numpy as np

c = compare_exploration(
    k=3,
    N=100,
    step=0.5,
    erange=np.arange(0,0.5,0.1),
    figure=True
)
